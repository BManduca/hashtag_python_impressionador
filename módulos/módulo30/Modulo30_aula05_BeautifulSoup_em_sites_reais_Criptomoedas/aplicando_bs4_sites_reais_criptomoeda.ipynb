# %% [markdown]
# ## Aplicando BeautifulSoup em sites reais
# * **Obs.:** Estaremos utilizando a lib requests para as requisições, porém, nem todos os sites aceitam que seja realizado esse tipo de ação

# %%
from bs4 import BeautifulSoup
import requests
import re


link = 'https://coinmarketcap.com'
# enviando sinal de requisicao para o site
# basicamente dentro de request_site -> tem o código puro do site
request_site = requests.get(link)

# aplicando um parser para transformar o texto presente em request_title em código
site = BeautifulSoup(request_site.text, "html.parser")

# %%
tbody_coins = site.find('tbody')

linhas_body_coins = tbody_coins.find_all('tr')

# %%
# trazendo informações das moedas -> Nome, Símbolo e Valor
for linha in linhas_body_coins:
    try:
        nome_moeda = linha.find(class_="coin-item-name").text
        simbolo_moeda = linha.find(class_="coin-item-symbol").text
        # para aplicação de RE, precisa tomar cuidado com os devidos caracteres especiais: $, /, [], {}, (), ^, .
        # pois eles podem ser entendidos como código e não texto. Para que isso não ocorra, basta colocar / antes do caracter
        valor_moeda = linha.find(string=re.compile(r"\$"))
        print(f'Moeda: {nome_moeda} | Símbolo: {simbolo_moeda} | Preço: {valor_moeda.text}')
    except AttributeError:
        break
# Out:
# Moeda: Bitcoin | Símbolo: BTC | Preço: $83,367.74
# Moeda: Ethereum | Símbolo: ETH | Preço: $1,566.46
# Moeda: Tether | Símbolo: USDT | Preço: $0.9994
# Moeda: XRP | Símbolo: XRP | Preço: $2.02
# Moeda: BNB | Símbolo: BNB | Preço: $585.97
# Moeda: Solana | Símbolo: SOL | Preço: $120.81
# Moeda: USDC | Símbolo: USDC | Preço: $0.9998
# Moeda: Dogecoin | Símbolo: DOGE | Preço: $0.1599
# Moeda: TRON | Símbolo: TRX | Preço: $0.2434
# Moeda: Cardano | Símbolo: ADA | Preço: $0.6238

# %%
for linha in linhas_body_coins:
    '''
        get_text() -> da a possibilidade de utilizar um separator, para 
        melhorar a visualização dos dados. Esta é a principal diferença do text para o get_text()
    '''
    text_trs_coins = linha.get_text(separator=";")
    lista_textos = text_trs_coins.split(";")
    if lista_textos[2] != "$":
        name_coin = lista_textos[1]
        simbol_coin = lista_textos[2]
        price_coin = lista_textos[3]
    else:
        name_coin = lista_textos[0]
        simbol_coin = lista_textos[1]
        price_coin = lista_textos[3]

    print(f'Moeda: {name_coin} | Símbolo: {simbol_coin} | Preço: {price_coin}')
# Out:
# Moeda: Bitcoin | Símbolo: BTC | Preço: $83,367.74
# Moeda: Ethereum | Símbolo: ETH | Preço: $1,566.46
# Moeda: Tether | Símbolo: USDT | Preço: $0.9994
# Moeda: XRP | Símbolo: XRP | Preço: $2.02
# Moeda: BNB | Símbolo: BNB | Preço: $585.97
# Moeda: Solana | Símbolo: SOL | Preço: $120.81
# Moeda: USDC | Símbolo: USDC | Preço: $0.9998
# Moeda: Dogecoin | Símbolo: DOGE | Preço: $0.1599
# Moeda: TRON | Símbolo: TRX | Preço: $0.2434
# Moeda: Cardano | Símbolo: ADA | Preço: $0.6238
# Moeda: UNUS SED LEO | Símbolo: LEO | Preço: 9.38
# Moeda: Chainlink | Símbolo: LINK | Preço: 12.65
# Moeda: Avalanche | Símbolo: AVAX | Preço: 19.12
# Moeda: Toncoin | Símbolo: TON | Preço: 2.93
# Moeda: Stellar | Símbolo: XLM | Preço: 0.23
# Moeda: Shiba Inu | Símbolo: SHIB | Preço: 0.00
# Moeda: Sui | Símbolo: SUI | Preço: 2.19
# Moeda: Hedera | Símbolo: HBAR | Preço: 0.17
# Moeda: Bitcoin Cash | Símbolo: BCH | Preço: 312.86
# Moeda: MANTRA | Símbolo: OM | Preço: 6.40
# Moeda: Litecoin | Símbolo: LTC | Preço: 76.15
# Moeda: Polkadot | Símbolo: DOT | Preço: 3.55
# Moeda: Dai | Símbolo: DAI | Preço: 1.00
# Moeda: Hyperliquid | Símbolo: HYPE | Preço: 15.72
# Moeda: Bitget Token | Símbolo: BGB | Preço: 4.30
# Moeda: Ethena USDe | Símbolo: USDe | Preço: 1.00
# Moeda: Pi | Símbolo: PI | Preço: 0.64
# Moeda: Monero | Símbolo: XMR | Preço: 206.17
# Moeda: Uniswap | Símbolo: UNI | Preço: 5.23
# Moeda: OKB | Símbolo: OKB | Preço: 53.33
# Moeda: Pepe | Símbolo: PEPE | Preço: 0.00
# Moeda: Aptos | Símbolo: APT | Preço: 4.79
# Moeda: Ondo | Símbolo: ONDO | Preço: 0.89
# Moeda: GateToken | Símbolo: GT | Preço: 22.31
# Moeda: NEAR Protocol | Símbolo: NEAR | Preço: 2.09
# Moeda: Internet Computer | Símbolo: ICP | Preço: 5.03
# Moeda: Mantle | Símbolo: MNT | Preço: 0.70
# Moeda: Cronos | Símbolo: CRO | Preço: 0.09
# Moeda: Ethereum Classic | Símbolo: ETC | Preço: 15.18
# Moeda: Bittensor | Símbolo: TAO | Preço: 250.17
# Moeda: Aave | Símbolo: AAVE | Preço: 135.92
# Moeda: Kaspa | Símbolo: KAS | Preço: 0.08
# Moeda: Render | Símbolo: RENDER | Preço: 3.71
# Moeda: VeChain | Símbolo: VET | Preço: 0.02
# Moeda: POL (prev. MATIC) | Símbolo: POL | Preço: 0.18
# Moeda: First Digital USD | Símbolo: FDUSD | Preço: 1.00
# Moeda: Ethena | Símbolo: ENA | Preço: 0.31
# Moeda: Cosmos | Símbolo: ATOM | Preço: 4.26
# Moeda: OFFICIAL TRUMP | Símbolo: TRUMP | Preço: 8.04
# Moeda: Filecoin | Símbolo: FIL | Preço: 2.45
# Moeda: Algorand | Símbolo: ALGO | Preço: 0.18
# Moeda: Celestia | Símbolo: TIA | Preço: 2.52
# Moeda: Sonic (prev. FTM) | Símbolo: S | Preço: 0.48
# Moeda: Arbitrum | Símbolo: ARB | Preço: 0.29
# Moeda: KuCoin Token | Símbolo: KCS | Preço: 10.46
# Moeda: DeXe | Símbolo: DEXE | Preço: 14.82
# Moeda: XDC Network | Símbolo: XDC | Preço: 0.07
# Moeda: Maker | Símbolo: MKR | Preço: 1331.44
# Moeda: Optimism | Símbolo: OP | Preço: 0.66
# Moeda: Jupiter | Símbolo: JUP | Preço: 0.38
# Moeda: Artificial Superintelligence Alliance | Símbolo: FET | Preço: 0.45
# Moeda: Story | Símbolo: IP | Preço: 3.97
# Moeda: Bonk | Símbolo: BONK | Preço: 0.00
# Moeda: EOS | Símbolo: EOS | Preço: 0.62
# Moeda: Flare | Símbolo: FLR | Preço: 0.02
# Moeda: Stacks | Símbolo: STX | Preço: 0.61
# Moeda: Worldcoin | Símbolo: WLD | Preço: 0.74
# Moeda: Fartcoin | Símbolo: FARTCOIN | Preço: 0.88
# Moeda: PayPal USD | Símbolo: PYUSD | Preço: 1.00
# Moeda: Injective | Símbolo: INJ | Preço: 8.25
# Moeda: Movement | Símbolo: MOVE | Preço: 0.33
# Moeda: Tether Gold | Símbolo: XAUt | Preço: 3251.45
# Moeda: Curve DAO Token | Símbolo: CRV | Preço: 0.61
# Moeda: Quant | Símbolo: QNT | Preço: 65.36
# Moeda: The Graph | Símbolo: GRT | Preço: 0.08
# Moeda: Sei | Símbolo: SEI | Preço: 0.16
# Moeda: Immutable | Símbolo: IMX | Preço: 0.42
# Moeda: Four | Símbolo: FORM | Preço: 1.96
# Moeda: AB | Símbolo: AB | Preço: 0.01
# Moeda: PAX Gold | Símbolo: PAXG | Preço: 3262.54
# Moeda: Theta Network | Símbolo: THETA | Preço: 0.73
# Moeda: JasmyCoin | Símbolo: JASMY | Preço: 0.01
# Moeda: Nexo | Símbolo: NEXO | Preço: 1.05
# Moeda: Onyxcoin | Símbolo: XCN | Preço: 0.02
# Moeda: Lido DAO | Símbolo: LDO | Preço: 0.73
# Moeda: The Sandbox | Símbolo: SAND | Preço: 0.26
# Moeda: Gala | Símbolo: GALA | Preço: 0.01
# Moeda: Walrus | Símbolo: WAL | Preço: 0.49
# Moeda: Kaia | Símbolo: KAIA | Preço: 0.10
# Moeda: BitTorrent [New] | Símbolo: BTT | Preço: 0.00
# Moeda: IOTA | Símbolo: IOTA | Preço: 0.16
# Moeda: PancakeSwap | Símbolo: CAKE | Preço: 2.00
# Moeda: Bitcoin SV | Símbolo: BSV | Preço: 28.59
# Moeda: Tezos | Símbolo: XTZ | Preço: 0.54
# Moeda: Zcash | Símbolo: ZEC | Preço: 35.36
# Moeda: Flow | Símbolo: FLOW | Preço: 0.35
# Moeda: Jito | Símbolo: JTO | Preço: 1.72
# Moeda: Core | Símbolo: CORE | Preço: 0.54
# Moeda: FLOKI | Símbolo: FLOKI | Preço: 0.00
# Moeda: Pendle | Símbolo: PENDLE | Preço: 3.25
