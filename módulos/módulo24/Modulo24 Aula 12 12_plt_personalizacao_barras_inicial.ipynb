# %% [markdown]
# # Mais personalizações possíveis

# %% [markdown]
# ## Gráfico de barras para apresentação
#
# Considere que você tem as quantidades de produtos vendidos em uma loja. Faça um gráfico de barras horizontais.

# %%
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/brunnomanduca/Documents/Repositórios/MyGithub/hashtag_python_impressionador/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

# %%
plt.bar(produtos, quantidades)

plt.xlabel('Produtos')
plt.ylabel('Quantidades')

plt.show()

# %%
barras = plt.barh(produtos, quantidades)

# adicionando rotulos em cada barra
plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

plt.box(False)

plt.xticks([])
plt.tick_params(axis='y', length=0)

plt.title('Quantidade de produtos vendidos')

plt.show()

# %%
from cycler import cycler

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

rotulos = [valor if valor == max(quantidades) else '' for valor in quantidades]

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=rotulos, padding=3, fontsize=10, fontweight='bold')

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
# configuração em tempo de execução
plt.rc('axes', prop_cycle=ciclo_cores)

plt.box(False)

plt.xticks([])
plt.tick_params(axis='y', length=0)

for i, barra in enumerate(barras):
    # so entrar no loop de verificação se o i for difente da posição do maior elemento presente em quantidades.
    if i != quantidades.index(max(quantidades)):
        barras[i].set_color(cores[1])
        # diminuindo a tonalidade
        barras[i].set_alpha(0.3)

plt.title('Quantidade de produtos vendidos')

plt.show()

# %%
print(quantidades)
print(produtos)

# em python para juntas duas listas, utilizamos o zip
list_quantidades_produtos = list(zip(quantidades, produtos))
print(list_quantidades_produtos)

print('\n')
# o sorted pega sempre a primeira posição e considera a mesma como uma referencia
dados_ordenados = sorted(list_quantidades_produtos)
print(dados_ordenados)

quantidades_ordenadas = [dado[0] for dado in dados_ordenados]
print(quantidades_ordenadas)

produtos_ordenados = [dado[1] for dado in dados_ordenados]
print(produtos_ordenados)
# Out:
# [23, 45, 17, 30, 37]
# ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
# [(23, 'Produto A'), (45, 'Produto B'), (17, 'Produto C'), (30, 'Produto D'), (37, 'Produto E')]
#
#
# [(17, 'Produto C'), (23, 'Produto A'), (30, 'Produto D'), (37, 'Produto E'), (45, 'Produto B')]
# [17, 23, 30, 37, 45]
# ['Produto C', 'Produto A', 'Produto D', 'Produto E', 'Produto B']

# %%
from cycler import cycler

rotulos = [valor if valor == max(quantidades_ordenadas) else '' for valor in quantidades_ordenadas]

barras = plt.barh(produtos_ordenados, quantidades_ordenadas)

plt.bar_label(barras, labels=rotulos, padding=3, fontsize=10, fontweight='bold')

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
# configuração em tempo de execução
plt.rc('axes', prop_cycle=ciclo_cores)

plt.box(False)

plt.xticks([])
plt.tick_params(axis='y', length=0)

for i, barra in enumerate(barras):
    # so entrar no loop de verificação se o i for difente da posição do maior elemento presente em quantidades.
    if i != quantidades_ordenadas.index(max(quantidades_ordenadas)):
        barras[i].set_color(cores[1])
        # diminuindo a tonalidade
        barras[i].set_alpha(0.3)

plt.title('Quantidade de produtos vendidos')

plt.show()

# %%
from cycler import cycler

rotulos = [valor if valor == max(quantidades_ordenadas) else '' for valor in quantidades_ordenadas]

barras = plt.barh(produtos_ordenados, quantidades_ordenadas)

plt.bar_label(barras, labels=rotulos, padding=3, fontsize=10, fontweight='bold')

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
# configuração em tempo de execução
plt.rc('axes', prop_cycle=ciclo_cores)

plt.box(False)

plt.xticks([])
plt.tick_params(axis='y', length=0)

for i, barra in enumerate(barras):
    # so entrar no loop de verificação se o i for difente da posição do maior elemento presente em quantidades.
    if i != quantidades_ordenadas.index(max(quantidades_ordenadas)):
        barras[i].set_color(cores[1])
        # diminuindo a tonalidade
        barras[i].set_alpha(0.3)

plt.title('Quantidade de produtos vendidos')

# 'pegando' o sistema de eixos e inverter o eixo y
plt.gca().invert_yaxis()

plt.show()

# %%
from cycler import cycler

rotulos = [valor if valor == max(quantidades_ordenadas) else '' for valor in quantidades_ordenadas]

barras = plt.bar(produtos_ordenados, quantidades_ordenadas)

plt.bar_label(barras, labels=rotulos, padding=3, fontsize=10, fontweight='bold')

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
# configuração em tempo de execução
plt.rc('axes', prop_cycle=ciclo_cores)

plt.box(False)

plt.yticks([])
plt.tick_params(axis='x', length=0)

for i, barra in enumerate(barras):
    # so entrar no loop de verificação se o i for difente da posição do maior elemento presente em quantidades.
    if i != quantidades_ordenadas.index(max(quantidades_ordenadas)):
        barras[i].set_color(cores[1])
        # diminuindo a tonalidade
        barras[i].set_alpha(0.3)

plt.title('Quantidade de produtos vendidos')

# 'pegando' o sistema de eixos e inverter o eixo x
plt.gca().invert_xaxis()

plt.show()
